# %% [markdown]
# Marketing Analytics9

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import seaborn as sns
import warnings
import re
import os
sns.set()
pd.set_option("display.max_columns", None)
pd.set_option("display.width", None)
warnings.filterwarnings("ignore")

sns.__version__
# Out:
# '0.11.1'

# %%
data = pd.read_csv("D:/Medium/2 Learned\Marketing Analytics/marketing_data.csv", index_col='ID', parse_dates=['Dt_Customer'])

data = data.rename(columns={
    'Dt_Customer':'Enrollment date',
    'Recency':'Days since last purchase',
    ' Income ':'Income'})

data['ID'] = data.index

data.head()
# Out:
#        Year_Birth   Education Marital_Status       Income  Kidhome  Teenhome  \
# ID
# 1826         1970  Graduation       Divorced  $84,835.00         0         0
# 1            1961  Graduation         Single  $57,091.00         0         0
# 10476        1958  Graduation        Married  $67,267.00         0         1
# 1386         1967  Graduation       Together  $32,474.00         1         1
# 5371         1989  Graduation         Single  $21,474.00         1         0
#
#       Enrollment date  Days since last purchase  MntWines  MntFruits  \
# ID
# 1826       2014-06-16                         0       189        104
# 1          2014-06-15                         0       464          5
# 10476      2014-05-13                         0       134         11
# 1386       2014-05-11                         0        10          0
# 5371       2014-04-08                         0         6         16
#
#        MntMeatProducts  MntFishProducts  MntSweetProducts  MntGoldProds  \
# ID
# 1826               379              111               189           218
# 1                   64                7                 0            37
# 10476               59               15                 2            30
# 1386                 1                0                 0             0
# 5371                24               11                 0            34
#
#        NumDealsPurchases  NumWebPurchases  NumCatalogPurchases  \
# ID
# 1826                   1                4                    4
# 1                      1                7                    3
# 10476                  1                3                    2
# 1386                   1                1                    0
# 5371                   2                3                    1
#
#        NumStorePurchases  NumWebVisitsMonth  AcceptedCmp3  AcceptedCmp4  \
# ID
# 1826                   6                  1             0             0
# 1                      7                  5             0             0
# 10476                  5                  2             0             0
# 1386                   2                  7             0             0
# 5371                   2                  7             1             0
#
#        AcceptedCmp5  AcceptedCmp1  AcceptedCmp2  Response  Complain Country  \
# ID
# 1826              0             0             0         1         0      SP
# 1                 0             0             1         1         0      CA
# 10476             0             0             0         0         0      US
# 1386              0             0             0         0         0     AUS
# 5371              0             0             0         1         0      SP
#
#           ID
# ID
# 1826    1826
# 1          1
# 10476  10476
# 1386    1386
# 5371    5371

# %%
print('Number of columns :',data.shape[1])
print('Number of records :',data.shape[0])
# Out:
# Number of columns : 28
# Number of records : 2240

# %% [markdown]
# Change "Income" column format from "$84,835.00" (String) to 84835.00 (Float) <br> By replacing comma(",") and "$" with empty string("").

# %%
# Another way
data['Income'].str.replace(r'[$,]','')
# Out:
# ID
# 1826     84835.00
# 1        57091.00
# 10476    67267.00
# 1386     32474.00
# 5371     21474.00
#            ...
# 10142    66476.00
# 5263     31056.00
# 22       46310.00
# 528      65819.00
# 4070     94871.00
# Name: Income, Length: 2240, dtype: object

# %%
def extract(x):
    if x is np.nan: return np.nan
    return float(re.sub(r'[$,]', "", str(x)))

data['Income'] = data['Income'].apply(extract)

# %% [markdown]
# Create table for each section of data

# %%
# Store customer's information
Customers = data.loc[:,:'Days since last purchase'].join(data[['Country']])  

# Store product's information
Products = data.loc[:,'MntWines':'MntGoldProds']     

# Store Purchases' information
Purchases = data.loc[:,'NumDealsPurchases':'NumWebVisitsMonth']    

# Store campaign's information
Campaigns = data.loc[:,'AcceptedCmp3':'AcceptedCmp2']     
Misc = data.loc[:,['Response','Complain']]

# %% [markdown]
# Create table for each type of data

# %%
category = data.select_dtypes(include='object')
numeric = data.select_dtypes(exclude='object')

# %% [markdown]
# Null values

# %%
pd.DataFrame(data.isnull().sum(), columns=['#Null values']).T
# Out:
#               Year_Birth  Education  Marital_Status  Income  Kidhome  \
# #Null values           0          0               0      24        0
#
#               Teenhome  Enrollment date  Days since last purchase  MntWines  \
# #Null values         0                0                         0         0
#
#               MntFruits  MntMeatProducts  MntFishProducts  MntSweetProducts  \
# #Null values          0                0                0                 0
#
#               MntGoldProds  NumDealsPurchases  NumWebPurchases  \
# #Null values             0                  0                0
#
#               NumCatalogPurchases  NumStorePurchases  NumWebVisitsMonth  \
# #Null values                    0                  0                  0
#
#               AcceptedCmp3  AcceptedCmp4  AcceptedCmp5  AcceptedCmp1  \
# #Null values             0             0             0             0
#
#               AcceptedCmp2  Response  Complain  Country  ID
# #Null values             0         0         0        0   0

# %% [markdown]
# There're 24 detectable null values in "Income" column. However, we still need to check for other missing values since sometimes missing values are denoted as, for example, "Unknown" for categorical data or -1 for numerical data.

# %%
for f in category.columns:
    print(category[f].value_counts())
    print('***********************************')
# Out:
# Graduation    1127
# PhD            486
# Master         370
# 2n Cycle       203
# Basic           54
# Name: Education, dtype: int64
# ***********************************
# Married     864
# Together    580
# Single      480
# Divorced    232
# Widow        77
# Alone         3
# Absurd        2
# YOLO          2
# Name: Marital_Status, dtype: int64
# ***********************************
# SP     1095
# SA      337
# CA      268
# AUS     160
# IND     148
# GER     120
# US      109
# ME        3
# Name: Country, dtype: int64
# ***********************************

# %% [markdown]
# Inspecting each value counts in categorical columns -> there're no more missing value.

# %%
df = numeric.describe()

def custom_style(row):
    
    color = 'white'
    if row.name == 'min' or row.name == 'max':
        color = 'darkkhaki'

    return ['background-color: %s' % color]*len(row.values)

df.style.apply(custom_style, axis=1)
# Out:
# <style  type="text/css" >
# #T_dcf53_row0_col0,#T_dcf53_row0_col1,#T_dcf53_row0_col2,#T_dcf53_row0_col3,#T_dcf53_row0_col4,#T_dcf53_row0_col5,#T_dcf53_row0_col6,#T_dcf53_row0_col7,#T_dcf53_row0_col8,#T_dcf53_row0_col9,#T_dcf53_row0_col10,#T_dcf53_row0_col11,#T_dcf53_row0_col12,#T_dcf53_row0_col13,#T_dcf53_row0_col14,#T_dcf53_row0_col15,#T_dcf53_row0_col16,#T_dcf53_row0_col17,#T_dcf53_row0_col18,#T_dcf53_row0_col19,#T_dcf53_row0_col20,#T_dcf53_row0_col21,#T_dcf53_row0_col22,#T_dcf53_row0_col23,#T_dcf53_row1_col0,#T_dcf53_row1_col1,#T_dcf53_row1_col2,#T_dcf53_row1_col3,#T_dcf53_row1_col4,#T_dcf53_row1_col5,#T_dcf53_row1_col6,#T_dcf53_row1_col7,#T_dcf53_row1_col8,#T_dcf53_row1_col9,#T_dcf53_row1_col10,#T_dcf53_row1_col11,#T_dcf53_row1_col12,#T_dcf53_row1_col13,#T_dcf53_row1_col14,#T_dcf53_row1_col15,#T_dcf53_row1_col16,#T_dcf53_row1_col17,#T_dcf53_row1_col18,#T_dcf53_row1_col19,#T_dcf53_row1_col20,#T_dcf53_row1_col21,#T_dcf53_row1_col22,#T_dcf53_row1_col23,#T_dcf53_row2_col0,#T_dcf53_row2_col1,#T_dcf53_row2_col2,#T_dcf53_row2_col3,#T_dcf53_row2_col4,#T_dcf53_row2_col5,#T_dcf53_row2_col6,#T_dcf53_row2_col7,#T_dcf53_row2_col8,#T_dcf53_row2_col9,#T_dcf53_row2_col10,#T_dcf53_row2_col11,#T_dcf53_row2_col12,#T_dcf53_row2_col13,#T_dcf53_row2_col14,#T_dcf53_row2_col15,#T_dcf53_row2_col16,#T_dcf53_row2_col17,#T_dcf53_row2_col18,#T_dcf53_row2_col19,#T_dcf53_row2_col20,#T_dcf53_row2_col21,#T_dcf53_row2_col22,#T_dcf53_row2_col23,#T_dcf53_row4_col0,#T_dcf53_row4_col1,#T_dcf53_row4_col2,#T_dcf53_row4_col3,#T_dcf53_row4_col4,#T_dcf53_row4_col5,#T_dcf53_row4_col6,#T_dcf53_row4_col7,#T_dcf53_row4_col8,#T_dcf53_row4_col9,#T_dcf53_row4_col10,#T_dcf53_row4_col11,#T_dcf53_row4_col12,#T_dcf53_row4_col13,#T_dcf53_row4_col14,#T_dcf53_row4_col15,#T_dcf53_row4_col16,#T_dcf53_row4_col17,#T_dcf53_row4_col18,#T_dcf53_row4_col19,#T_dcf53_row4_col20,#T_dcf53_row4_col21,#T_dcf53_row4_col22,#T_dcf53_row4_col23,#T_dcf53_row5_col0,#T_dcf53_row5_col1,#T_dcf53_row5_col2,#T_dcf53_row5_col3,#T_dcf53_row5_col4,#T_dcf53_row5_col5,#T_dcf53_row5_col6,#T_dcf53_row5_col7,#T_dcf53_row5_col8,#T_dcf53_row5_col9,#T_dcf53_row5_col10,#T_dcf53_row5_col11,#T_dcf53_row5_col12,#T_dcf53_row5_col13,#T_dcf53_row5_col14,#T_dcf53_row5_col15,#T_dcf53_row5_col16,#T_dcf53_row5_col17,#T_dcf53_row5_col18,#T_dcf53_row5_col19,#T_dcf53_row5_col20,#T_dcf53_row5_col21,#T_dcf53_row5_col22,#T_dcf53_row5_col23,#T_dcf53_row6_col0,#T_dcf53_row6_col1,#T_dcf53_row6_col2,#T_dcf53_row6_col3,#T_dcf53_row6_col4,#T_dcf53_row6_col5,#T_dcf53_row6_col6,#T_dcf53_row6_col7,#T_dcf53_row6_col8,#T_dcf53_row6_col9,#T_dcf53_row6_col10,#T_dcf53_row6_col11,#T_dcf53_row6_col12,#T_dcf53_row6_col13,#T_dcf53_row6_col14,#T_dcf53_row6_col15,#T_dcf53_row6_col16,#T_dcf53_row6_col17,#T_dcf53_row6_col18,#T_dcf53_row6_col19,#T_dcf53_row6_col20,#T_dcf53_row6_col21,#T_dcf53_row6_col22,#T_dcf53_row6_col23{
#             background-color:  white;
#         }#T_dcf53_row3_col0,#T_dcf53_row3_col1,#T_dcf53_row3_col2,#T_dcf53_row3_col3,#T_dcf53_row3_col4,#T_dcf53_row3_col5,#T_dcf53_row3_col6,#T_dcf53_row3_col7,#T_dcf53_row3_col8,#T_dcf53_row3_col9,#T_dcf53_row3_col10,#T_dcf53_row3_col11,#T_dcf53_row3_col12,#T_dcf53_row3_col13,#T_dcf53_row3_col14,#T_dcf53_row3_col15,#T_dcf53_row3_col16,#T_dcf53_row3_col17,#T_dcf53_row3_col18,#T_dcf53_row3_col19,#T_dcf53_row3_col20,#T_dcf53_row3_col21,#T_dcf53_row3_col22,#T_dcf53_row3_col23,#T_dcf53_row7_col0,#T_dcf53_row7_col1,#T_dcf53_row7_col2,#T_dcf53_row7_col3,#T_dcf53_row7_col4,#T_dcf53_row7_col5,#T_dcf53_row7_col6,#T_dcf53_row7_col7,#T_dcf53_row7_col8,#T_dcf53_row7_col9,#T_dcf53_row7_col10,#T_dcf53_row7_col11,#T_dcf53_row7_col12,#T_dcf53_row7_col13,#T_dcf53_row7_col14,#T_dcf53_row7_col15,#T_dcf53_row7_col16,#T_dcf53_row7_col17,#T_dcf53_row7_col18,#T_dcf53_row7_col19,#T_dcf53_row7_col20,#T_dcf53_row7_col21,#T_dcf53_row7_col22,#T_dcf53_row7_col23{
#             background-color:  darkkhaki;
#         }</style><table id="T_dcf53_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Year_Birth</th>        <th class="col_heading level0 col1" >Income</th>        <th class="col_heading level0 col2" >Kidhome</th>        <th class="col_heading level0 col3" >Teenhome</th>        <th class="col_heading level0 col4" >Days since last purchase</th>        <th class="col_heading level0 col5" >MntWines</th>        <th class="col_heading level0 col6" >MntFruits</th>        <th class="col_heading level0 col7" >MntMeatProducts</th>        <th class="col_heading level0 col8" >MntFishProducts</th>        <th class="col_heading level0 col9" >MntSweetProducts</th>        <th class="col_heading level0 col10" >MntGoldProds</th>        <th class="col_heading level0 col11" >NumDealsPurchases</th>        <th class="col_heading level0 col12" >NumWebPurchases</th>        <th class="col_heading level0 col13" >NumCatalogPurchases</th>        <th class="col_heading level0 col14" >NumStorePurchases</th>        <th class="col_heading level0 col15" >NumWebVisitsMonth</th>        <th class="col_heading level0 col16" >AcceptedCmp3</th>        <th class="col_heading level0 col17" >AcceptedCmp4</th>        <th class="col_heading level0 col18" >AcceptedCmp5</th>        <th class="col_heading level0 col19" >AcceptedCmp1</th>        <th class="col_heading level0 col20" >AcceptedCmp2</th>        <th class="col_heading level0 col21" >Response</th>        <th class="col_heading level0 col22" >Complain</th>        <th class="col_heading level0 col23" >ID</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_dcf53_level0_row0" class="row_heading level0 row0" >count</th>
#                         <td id="T_dcf53_row0_col0" class="data row0 col0" >2240.000000</td>
#                         <td id="T_dcf53_row0_col1" class="data row0 col1" >2216.000000</td>
#                         <td id="T_dcf53_row0_col2" class="data row0 col2" >2240.000000</td>
#                         <td id="T_dcf53_row0_col3" class="data row0 col3" >2240.000000</td>
#                         <td id="T_dcf53_row0_col4" class="data row0 col4" >2240.000000</td>
#                         <td id="T_dcf53_row0_col5" class="data row0 col5" >2240.000000</td>
#                         <td id="T_dcf53_row0_col6" class="data row0 col6" >2240.000000</td>
#                         <td id="T_dcf53_row0_col7" class="data row0 col7" >2240.000000</td>
#                         <td id="T_dcf53_row0_col8" class="data row0 col8" >2240.000000</td>
#                         <td id="T_dcf53_row0_col9" class="data row0 col9" >2240.000000</td>
#                         <td id="T_dcf53_row0_col10" class="data row0 col10" >2240.000000</td>
#                         <td id="T_dcf53_row0_col11" class="data row0 col11" >2240.000000</td>
#                         <td id="T_dcf53_row0_col12" class="data row0 col12" >2240.000000</td>
#                         <td id="T_dcf53_row0_col13" class="data row0 col13" >2240.000000</td>
#                         <td id="T_dcf53_row0_col14" class="data row0 col14" >2240.000000</td>
#                         <td id="T_dcf53_row0_col15" class="data row0 col15" >2240.000000</td>
#                         <td id="T_dcf53_row0_col16" class="data row0 col16" >2240.000000</td>
#                         <td id="T_dcf53_row0_col17" class="data row0 col17" >2240.000000</td>
#                         <td id="T_dcf53_row0_col18" class="data row0 col18" >2240.000000</td>
#                         <td id="T_dcf53_row0_col19" class="data row0 col19" >2240.000000</td>
#                         <td id="T_dcf53_row0_col20" class="data row0 col20" >2240.000000</td>
#                         <td id="T_dcf53_row0_col21" class="data row0 col21" >2240.000000</td>
#                         <td id="T_dcf53_row0_col22" class="data row0 col22" >2240.000000</td>
#                         <td id="T_dcf53_row0_col23" class="data row0 col23" >2240.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_dcf53_level0_row1" class="row_heading level0 row1" >mean</th>

# %% [markdown]
# Inspecting each numerical columns -> There's no weirdly low or high value.

# %% [markdown]
# We can conclude that there are only have missing values in "Income" column

# %%
'''
from sklearn.impute import KNNImputer

numeric_before_impute = numeric.drop(['Year_Birth','Enrollment date','ID'], axis=1).copy()

imputer = KNNImputer(missing_values=np.nan)
numeric_imputed = imputer.fit_transform(numeric_before_impute)

numeric_imputed = pd.DataFrame(numeric_imputed, 
                       index=numeric_before_impute.index, 
                       columns=numeric_before_impute.columns).join(numeric[['Year_Birth','Enrollment date','ID']])

'''
# Out:
# "\nfrom sklearn.impute import KNNImputer\n\nnumeric_before_impute = numeric.drop(['Year_Birth','Enrollment date','ID'], axis=1).copy()\n\nimputer = KNNImputer(missing_values=np.nan)\nnumeric_imputed = imputer.fit_transform(numeric_before_impute)\n\nnumeric_imputed = pd.DataFrame(numeric_imputed, \n                       index=numeric_before_impute.index, \n                       columns=numeric_before_impute.columns).join(numeric[['Year_Birth','Enrollment date','ID']])\n\n"

# %% [markdown]
# Create report() function to describe and visualize the numerical data.

# %%
def report(feature):
    fig, ax = plt.subplots(1,2)
    fig.set_size_inches(16,4)
    fig.suptitle(feature, fontsize=16)
    sns.histplot(data=numeric, x=feature, kde=True, ax=ax[0])
    sns.boxplot(data=numeric, x=feature, ax=ax[1])
    plt.show()

    print(numeric[feature].describe())

# %% [markdown]
# I'll create new column named "Age" and "Enroll_at_age" derived from "Year_Birth" and "Enrollment date" respectively.

# %%
from datetime import date

Age = date.today().year-numeric['Year_Birth']
numeric.insert(1, 'Age', Age,)

Enroll_at_age = numeric['Enrollment date'].dt.year - numeric['Year_Birth']
numeric.insert(6, 'Enroll_at_age', Enroll_at_age)

# %% [markdown]
# print the distribution report for numerical columns.

# %%
for col in numeric.columns:
    if col in ['Year_Birth','Enrollment date']: continue
    if col == 'AcceptedCmp3' : break
    report(col)
# Out:
# count    2240.000000
# mean       52.194196
# std        11.984069
# min        25.000000
# 25%        44.000000
# 50%        51.000000
# 75%        62.000000
# max       128.000000
# Name: Age, dtype: float64
# count      2216.000000
# mean      52247.251354
# std       25173.076661
# min        1730.000000
# 25%       35303.000000
# 50%       51381.500000
# 75%       68522.000000
# max      666666.000000
# Name: Income, dtype: float64
# count    2240.000000
# mean        0.444196
# std         0.538398
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         1.000000
# max         2.000000
# Name: Kidhome, dtype: float64
# count    2240.000000
# mean        0.506250
# std         0.544538
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         1.000000
# max         2.000000
# Name: Teenhome, dtype: float64
# count    2240.000000
# mean       44.222321
# std        12.022855
# min        16.000000
# 25%        36.000000
# 50%        43.000000
# 75%        54.000000
# max       121.000000
# Name: Enroll_at_age, dtype: float64
# count    2240.000000
# mean       49.109375
# std        28.962453
# min         0.000000
# 25%        24.000000
# 50%        49.000000
# 75%        74.000000
# max        99.000000
# Name: Days since last purchase, dtype: float64
# count    2240.000000
# mean      303.935714
# std       336.597393
# min         0.000000
# 25%        23.750000
# 50%       173.500000
# 75%       504.250000
# max      1493.000000
# Name: MntWines, dtype: float64
# count    2240.000000
# mean       26.302232
# std        39.773434
# min         0.000000
# 25%         1.000000
# 50%         8.000000
# 75%        33.000000
# max       199.000000
# Name: MntFruits, dtype: float64
# count    2240.000000
# mean      166.950000
# std       225.715373
# min         0.000000
# 25%        16.000000
# 50%        67.000000
# 75%       232.000000
# max      1725.000000
# Name: MntMeatProducts, dtype: float64
# count    2240.000000
# mean       37.525446
# std        54.628979
# min         0.000000
# 25%         3.000000
# 50%        12.000000
# 75%        50.000000
# max       259.000000
# Name: MntFishProducts, dtype: float64
# count    2240.000000
# mean       27.062946
# std        41.280498
# min         0.000000
# 25%         1.000000
# 50%         8.000000
# 75%        33.000000
# max       263.000000
# Name: MntSweetProducts, dtype: float64
# count    2240.000000
# mean       44.021875
# std        52.167439
# min         0.000000
# 25%         9.000000
# 50%        24.000000
# 75%        56.000000
# max       362.000000
# Name: MntGoldProds, dtype: float64
# count    2240.000000
# mean        2.325000
# std         1.932238
# min         0.000000
# 25%         1.000000
# 50%         2.000000
# 75%         3.000000
# max        15.000000
# Name: NumDealsPurchases, dtype: float64
# count    2240.000000
# mean        4.084821
# std         2.778714
# min         0.000000
# 25%         2.000000
# 50%         4.000000
# 75%         6.000000
# max        27.000000
# Name: NumWebPurchases, dtype: float64
# count    2240.000000
# mean        2.662054
# std         2.923101
# min         0.000000
# 25%         0.000000
# 50%         2.000000
# 75%         4.000000
# max        28.000000
# Name: NumCatalogPurchases, dtype: float64
# count    2240.000000
# mean        5.790179
# std         3.250958
# min         0.000000
# 25%         3.000000
# 50%         5.000000
# 75%         8.000000
# max        13.000000
# Name: NumStorePurchases, dtype: float64
# count    2240.000000
# mean        5.316518
# std         2.426645
# min         0.000000
# 25%         3.000000
# 50%         6.000000
# 75%         7.000000
# max        20.000000
# Name: NumWebVisitsMonth, dtype: float64

# %% [markdown]
# After we get some sense of distribution of each numerical column, next, we'll analyze them.

# %% [markdown]
# Age
# There're 3 people with ages 128, 122, and 121 whose Enrollment_at_age are 113, 114, and 121 respectively which is quite impossible.

# %%
numeric[numeric['Age']>80]
# Out:
#        Year_Birth  Age   Income  Kidhome  Teenhome Enrollment date  \
# ID
# 11004        1893  128  60182.0        0         1      2014-05-17
# 1150         1899  122  83532.0        0         0      2013-09-26
# 6663         1940   81  51141.0        0         0      2013-07-08
# 7829         1900  121  36640.0        1         0      2013-09-26
#
#        Enroll_at_age  Days since last purchase  MntWines  MntFruits  \
# ID
# 11004            121                        23         8          0
# 1150             114                        36       755        144
# 6663              73                        96       144          0
# 7829             113                        99        15          6
#
#        MntMeatProducts  MntFishProducts  MntSweetProducts  MntGoldProds  \
# ID
# 11004                5                7                 0             2
# 1150               562              104                64           224
# 6663                 7                0                 0             6
# 7829                 8                7                 4            25
#
#        NumDealsPurchases  NumWebPurchases  NumCatalogPurchases  \
# ID
# 11004                  1                1                    0
# 1150                   1                4                    6
# 6663                   1                3                    1
# 7829                   1                2                    1
#
#        NumStorePurchases  NumWebVisitsMonth  AcceptedCmp3  AcceptedCmp4  \
# ID
# 11004                  2                  4             0             0
# 1150                   4                  1             0             0
# 6663                   4                  5             0             0
# 7829                   2                  5             0             0
#
#        AcceptedCmp5  AcceptedCmp1  AcceptedCmp2  Response  Complain     ID
# ID
# 11004             0             0             0         0         0  11004
# 1150              1             0             0         0         0   1150
# 6663              0             0             0         0         0   6663
# 7829              0             0             0         0         1   7829

# %% [markdown]
# According to Wikipedia, there're no person alives at that age in 20 century.
# We can conclude that there were some mistakes in these records. So, I'll mark their "Year_Birth", "Age", "Enroll_at_age" Null.

# %%
temp = numeric[numeric['Age']>120].index
numeric.loc[temp, ["Year_Birth", "Age", "Enroll_at_age"]] = np.nan

# %% [markdown]
# Income

# %%
numeric[numeric['Income']>160000]
# Out:
#       Year_Birth   Age    Income  Kidhome  Teenhome Enrollment date  \
# ID
# 1501      1982.0  39.0  160803.0        0         0      2012-08-04
# 9432      1977.0  44.0  666666.0        1         0      2013-06-02
# 1503      1976.0  45.0  162397.0        1         1      2013-06-03
#
#       Enroll_at_age  Days since last purchase  MntWines  MntFruits  \
# ID
# 1501           30.0                        21        55         16
# 9432           36.0                        23         9         14
# 1503           37.0                        31        85          1
#
#       MntMeatProducts  MntFishProducts  MntSweetProducts  MntGoldProds  \
# ID
# 1501             1622               17                 3             4
# 9432               18                8                 1            12
# 1503               16                2                 1             2
#
#       NumDealsPurchases  NumWebPurchases  NumCatalogPurchases  \
# ID
# 1501                 15                0                   28
# 9432                  4                3                    1
# 1503                  0                0                    0
#
#       NumStorePurchases  NumWebVisitsMonth  AcceptedCmp3  AcceptedCmp4  \
# ID
# 1501                  1                  0             0             0
# 9432                  3                  6             0             0
# 1503                  1                  1             0             0
#
#       AcceptedCmp5  AcceptedCmp1  AcceptedCmp2  Response  Complain    ID
# ID
# 1501             0             0             0         0         0  1501
# 9432             0             0             0         0         0  9432
# 1503             0             0             0         0         0  1503

# %% [markdown]
# There is one person with ID 9432 that has very high income which is not impossible. Moreover, when consider age and enrollment date, it seems OK. So, I decide to do not thing with him.
#
# Amount of product, number of purchases features are exponentially distributed which not unusual.

# %% [markdown]
# After we have looked into missing values and outliers, we then analyze all of the features to get some insight into them.
#
# Considering Enrollment date, we can see the total number of enrollment in each year in the following bar graph.

# %%
plt.bar(height = numeric['Enrollment date'].dt.year.value_counts()[[2012,2013,2014]], x=['2012','2013','2014'])
plt.title('Number of enrollment in each year')
plt.show()

# %% [markdown]
# However in 2012, the data is gathered from 2012/08 and ,in 2014, data is gathered until 2014/07. Thus, that makes sense that 2013 have the greatest number of enrollment. The graph below shows the average number of enrollment over time.

# %%
df = pd.pivot_table(numeric, values='ID', index='Enrollment date', aggfunc='count')
df['count'] = df['ID'].rolling(10).mean()
df['Year'] = df.index.year.astype('category')

fig, ax = plt.subplots()
fig.set_size_inches(20,6)

sns.lineplot(data=df, x='Enrollment date', y='count', ax=ax, hue='Year')
ax.set_ylabel('Average enrollments')
ax.xaxis.set_major_locator(mdates.MonthLocator())
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y - %m'))
plt.xticks(rotation=40)
plt.show()

# %% [markdown]
# Mean and Median of Income in each country

# %%
# This time, we need to exclude the outlier in "Income" column before caculating any statistics.
numeric_analysis = numeric[numeric['Income']!=666666]

df = pd.pivot_table(numeric_analysis.join(category[['Country']]), 
                     values='Income', 
                     index='Country', 
                     aggfunc={'Income':['mean','median']})
df.plot(kind='bar')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.ylabel('Income')
plt.show()

# %% [markdown]
# We'll go deeper by looking into relationship between age and income in each country.
# We noticed that "ME" country have only 3 observations. We won't drop them. Instead, we'll keep that caution in mind while we're doing analysis.

# %%
temp = numeric_analysis[['Income','Age']].join(category[['Country']])
sns.lmplot(data=temp, y='Income', x='Age', col='Country', col_wrap=4, line_kws={'color': 'darkorange'}, scatter_kws={'color':'teal'})
plt.ylim(0,200000)
plt.show()

# %% [markdown]
# Income in each education level.

# %%
df = pd.pivot_table(numeric_analysis.join(category[['Education']]), 
               values='Income', 
               index='Education', 
               aggfunc={'Income':['count','mean','median']})

df[['mean','median']].plot(kind='bar')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.ylabel('Income')
plt.xlabel('')
plt.title('Income in each education level')
plt.show()

df
# Out:
#             count          mean   median
# Education
# 2n Cycle      200  47633.190000  46805.0
# Basic          54  20306.259259  20744.0
# Graduation   1115  52169.749776  51983.0
# Master        365  52917.534247  50943.0
# PhD           481  56145.313929  55212.0

# %%
del numeric_analysis

# %% [markdown]
# I'll create new column "Total products amount" : define a total number of products purchased by each customer.

# %%
numeric['Total products amount'] = np.sum(Products, axis=1)

# %% [markdown]
# We'll looking into proportion of the number of purchases in each channel ('Deal', 'Web', 'Catalog', 'Store') to see the performance of each channel.
# We see that 39% of all purchase is in store, 27.5% in web, 15.6% in deal, and 17.9% by catalog. We can conclude that ,from the data, more than half of the customers purchased in store and website.

# %%
total_purchase_each = np.sum(Purchases.iloc[:,:-1], axis=0)

percent_purchase_each = total_purchase_each/np.sum(total_purchase_each)*100

def plot_pie_chart(labels, sizes: pd.Series, title):
    fig, ax = plt.subplots()
    fig.suptitle(title, fontsize=16)
    fig.set_size_inches(5,5)
    ax.pie(sizes, labels=labels, autopct='%1.1f%%',
            shadow=True, startangle=90)
    ax.axis('equal')  
    plt.show()
    print(sizes.sort_values(ascending=False))
    

plot_pie_chart(labels=['Deal','Web','Catalog','Store'], sizes=percent_purchase_each, title='Purchases in each channel')
# Out:
# NumStorePurchases      38.959479
# NumWebPurchases        27.484906
# NumCatalogPurchases    17.911748
# NumDealsPurchases      15.643868
# dtype: float64

# %% [markdown]
#  looking into total number of purchases in each country.
# We see that most of the customers are from Spain

# %%
if 'Total purchase' not in Purchases.columns:
    Purchases['Total purchase'] = np.sum(Purchases, axis=1)

Purchase_category = Purchases.join(category)

Purchase_country_summary = pd.pivot_table(Purchase_category, 
                                          values='Total purchase', 
                                          index='Country', 
                                          aggfunc={'Total purchase':['sum']})

Purchase_country_summary.plot(kind='bar')
plt.title('Total purchases in each country')
plt.show()

# %% [markdown]
# We wanted to know which product was the most popular. So, we'll look into Overall proportion of products purchased.
# We see that 50.2% of all products purchased by all customers is wine and the second place(27.6%) is meat.

# %%
sum_each_product = np.sum(Products, axis=0)

plot_pie_chart(sizes=sum_each_product/np.sum(sum_each_product)*100, 
               labels=['Wine','Fruit','Meat','Fish','Sweet','Gold'],
              title='Overall %Products')
# Out:
# MntWines            50.171114
# MntMeatProducts     27.558681
# MntGoldProds         7.266755
# MntFishProducts      6.194380
# MntSweetProducts     4.467320
# MntFruits            4.341748
# dtype: float64

# %% [markdown]
# we want to know the average purchase behavior of each customer. We'll looking into Average proportion of each product purchased by one ID
# From 100% of all product each person puurchased*, we see that 45.8% will be wine, 24.95% meat product, 12% gold ptoduct, 7% fish product, 5% sweet, 4.9% fruit product.

# %%
if 'Total' not in Products.columns:
    Products['Total'] = np.sum(Products, axis=1)

Each_ID_Products = Products.apply(lambda x:x/x[-1]*100, axis=1)

Avg_Each_ID_Products = np.mean(Each_ID_Products, axis=0)

# %%
plot_pie_chart(sizes = Avg_Each_ID_Products[:-1], 
               labels=['Wine','Fruit','Meat','Fish','Sweet','Gold'],
               title='Average Product for each ID')
# Out:
# MntWines            45.848136
# MntMeatProducts     24.950802
# MntGoldProds        12.019649
# MntFishProducts      7.153233
# MntSweetProducts     5.077723
# MntFruits            4.950457
# dtype: float64

# %% [markdown]
# We wanted to know the performance of each campaign we conducted. Below, the bar graph and pie-chart show the number of acceptance and success rates in each campaign.
# We see that camapign2 might have some problems because it's very less accepted while other campaigns are accepted at a similar rate.

# %%
each_campaign = np.sum(Campaigns,axis=0)

CR_each_canpaign = each_campaign/len(Campaigns)*100

# %%
fig, ax = plt.subplots(1,2)
fig.set_size_inches(15,4)

cam_color = ['steelblue','peru','olivedrab','teal','sienna']

ax[0].barh(y=['Campaign 3','Campaign 4','Campaign 5','Campaign 1','Campaign 2'], 
           width=each_campaign.values, color=cam_color)
ax[0].set_xlabel('# success')

ax[1].pie(x=CR_each_canpaign, labels=['Campaign 3','Campaign 4','Campaign 5','Campaign 1','Campaign 2'],
         autopct='%1.1f%%', shadow=True, startangle=90, colors=cam_color)
ax[1].axis('equal')
ax[1].set_xlabel('Overall each campaign\'s success rate')

plt.show()

# %% [markdown]
# We want to know if 'Age' have some noticeable effect on campaign acceptance.
# Although there's no obvious trend, we still can see that campaign3 is likely to be accepted in younger customers than campaign4 while other campaigns are uniformly accepted in different ages.

# %%
fig, ax = plt.subplots(1,len(Campaigns.columns), sharey=True)
i=0
fig.set_size_inches(20,6)

for campaign in Campaigns.columns:
    sns.histplot(data=numeric[numeric[campaign]==1], x = 'Age', ax=ax[i])
    ax[i].set_ylim(0,40)
    ax[i].set_title(campaign)    
    i+=1
    
plt.show()

# %% [markdown]
# we'll see if there's that effect in different countries. The table below shows the overall conversion rate in each country.
#
# The overall conversion rate is around 30%.
# We see that 'ME' has the best conversion rate but there is only 3 observation in this country. So, it's not significant.
# Other than 'ME', campaigns in 'SP' and 'CA' get the best conversion rate(32.4%).
# The worst rate is in 'AUS' which is 21.8%.

# %%
Campaigns_category = Campaigns.join(category)
Campaigns_category['Total accept'] = np.sum(Campaigns, axis=1)

summary_country = pd.pivot_table(Campaigns_category, 
                                   values='Total accept', 
                                   index='Country', 
                                   aggfunc={'Total accept':['sum','count']})

summary_country['CR'] = summary_country['sum']/summary_country['count']
summary_country.rename(columns={'count':'#customers', 'sum':'Total accept'}).style.background_gradient(sns.light_palette('khaki', as_cmap=True), 
                                                                                                       subset=pd.IndexSlice[:, ['CR']])
# Out:
# <style  type="text/css" >
# #T_ebcb8_row0_col2{
#             background-color:  #f2f1e9;
#             color:  #000000;
#         }#T_ebcb8_row1_col2,#T_ebcb8_row6_col2{
#             background-color:  #f0e793;
#             color:  #000000;
#         }#T_ebcb8_row2_col2{
#             background-color:  #f0e899;
#             color:  #000000;
#         }#T_ebcb8_row3_col2{
#             background-color:  #f1edc4;
#             color:  #000000;
#         }#T_ebcb8_row4_col2{
#             background-color:  #f0e68c;
#             color:  #000000;
#         }#T_ebcb8_row5_col2{
#             background-color:  #f1edcb;
#             color:  #000000;
#         }#T_ebcb8_row7_col2{
#             background-color:  #f2efd9;
#             color:  #000000;
#         }</style><table id="T_ebcb8_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >#customers</th>        <th class="col_heading level0 col1" >Total accept</th>        <th class="col_heading level0 col2" >CR</th>    </tr>    <tr>        <th class="index_name level0" >Country</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_ebcb8_level0_row0" class="row_heading level0 row0" >AUS</th>
#                         <td id="T_ebcb8_row0_col0" class="data row0 col0" >160</td>
#                         <td id="T_ebcb8_row0_col1" class="data row0 col1" >35</td>
#                         <td id="T_ebcb8_row0_col2" class="data row0 col2" >0.218750</td>
#             </tr>
#             <tr>
#                         <th id="T_ebcb8_level0_row1" class="row_heading level0 row1" >CA</th>
#                         <td id="T_ebcb8_row1_col0" class="data row1 col0" >268</td>
#                         <td id="T_ebcb8_row1_col1" class="data row1 col1" >87</td>
#                         <td id="T_ebcb8_row1_col2" class="data row1 col2" >0.324627</td>
#             </tr>
#             <tr>
#                         <th id="T_ebcb8_level0_row2" class="row_heading level0 row2" >GER</th>
#                         <td id="T_ebcb8_row2_col0" class="data row2 col0" >120</td>
#                         <td id="T_ebcb8_row2_col1" class="data row2 col1" >38</td>
#                         <td id="T_ebcb8_row2_col2" class="data row2 col2" >0.316667</td>
#             </tr>
#             <tr>
#                         <th id="T_ebcb8_level0_row3" class="row_heading level0 row3" >IND</th>
#                         <td id="T_ebcb8_row3_col0" class="data row3 col0" >148</td>
#                         <td id="T_ebcb8_row3_col1" class="data row3 col1" >39</td>
#                         <td id="T_ebcb8_row3_col2" class="data row3 col2" >0.263514</td>
#             </tr>
#             <tr>
#                         <th id="T_ebcb8_level0_row4" class="row_heading level0 row4" >ME</th>
#                         <td id="T_ebcb8_row4_col0" class="data row4 col0" >3</td>
#                         <td id="T_ebcb8_row4_col1" class="data row4 col1" >1</td>
#                         <td id="T_ebcb8_row4_col2" class="data row4 col2" >0.333333</td>
#             </tr>
#             <tr>
#                         <th id="T_ebcb8_level0_row5" class="row_heading level0 row5" >SA</th>
#                         <td id="T_ebcb8_row5_col0" class="data row5 col0" >337</td>
#                         <td id="T_ebcb8_row5_col1" class="data row5 col1" >86</td>
#                         <td id="T_ebcb8_row5_col2" class="data row5 col2" >0.255193</td>
#             </tr>
#             <tr>
#                         <th id="T_ebcb8_level0_row6" class="row_heading level0 row6" >SP</th>
#                         <td id="T_ebcb8_row6_col0" class="data row6 col0" >1095</td>
#                         <td id="T_ebcb8_row6_col1" class="data row6 col1" >355</td>
#                         <td id="T_ebcb8_row6_col2" class="data row6 col2" >0.324201</td>
#             </tr>
#             <tr>
#                         <th id="T_ebcb8_level0_row7" class="row_heading level0 row7" >US</th>
#                         <td id="T_ebcb8_row7_col0" class="data row7 col0" >109</td>
#                         <td id="T_ebcb8_row7_col1" class="data row7 col1" >26</td>
#                         <td id="T_ebcb8_row7_col2" class="data row7 col2" >0.238532</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# we'll see the average performance of each campaign in each country.
# Keep in mind that \"ME\" has only 3 observations.

# %%
temp = Campaigns_category.groupby(by='Country').agg(['mean'])
temp.drop(['ME'], axis=0, inplace=True)  # since "ME" have only 3 observations, I decided to drop it in this table.
temp.style.background_gradient(sns.light_palette('green', as_cmap=True))
# Out:
# <style  type="text/css" >
# #T_f9108_row0_col0,#T_f9108_row0_col1,#T_f9108_row0_col3,#T_f9108_row0_col4,#T_f9108_row0_col5,#T_f9108_row3_col2,#T_f9108_row6_col4{
#             background-color:  #ebf3eb;
#             color:  #000000;
#         }#T_f9108_row0_col2,#T_f9108_row1_col4,#T_f9108_row1_col5,#T_f9108_row2_col1,#T_f9108_row3_col0,#T_f9108_row5_col2,#T_f9108_row5_col3{
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }#T_f9108_row1_col0,#T_f9108_row4_col5{
#             background-color:  #9acb9a;
#             color:  #000000;
#         }#T_f9108_row1_col1{
#             background-color:  #088408;
#             color:  #f1f1f1;
#         }#T_f9108_row1_col2{
#             background-color:  #118811;
#             color:  #f1f1f1;
#         }#T_f9108_row1_col3{
#             background-color:  #229122;
#             color:  #000000;
#         }#T_f9108_row2_col0{
#             background-color:  #219021;
#             color:  #000000;
#         }#T_f9108_row2_col2{
#             background-color:  #54a954;
#             color:  #000000;
#         }#T_f9108_row2_col3,#T_f9108_row4_col4{
#             background-color:  #6eb66e;
#             color:  #000000;
#         }#T_f9108_row2_col4,#T_f9108_row6_col3{
#             background-color:  #3c9d3c;
#             color:  #000000;
#         }#T_f9108_row2_col5{
#             background-color:  #118911;
#             color:  #f1f1f1;
#         }#T_f9108_row3_col1{
#             background-color:  #4ba54a;
#             color:  #000000;
#         }#T_f9108_row3_col3,#T_f9108_row6_col2{
#             background-color:  #cce4cc;
#             color:  #000000;
#         }#T_f9108_row3_col4{
#             background-color:  #5dae5d;
#             color:  #000000;
#         }#T_f9108_row3_col5{
#             background-color:  #87c287;
#             color:  #000000;
#         }#T_f9108_row4_col0{
#             background-color:  #bdddbd;
#             color:  #000000;
#         }#T_f9108_row4_col1{
#             background-color:  #8cc58c;
#             color:  #000000;
#         }#T_f9108_row4_col2{
#             background-color:  #6db66d;
#             color:  #000000;
#         }#T_f9108_row4_col3{
#             background-color:  #65b265;
#             color:  #000000;
#         }#T_f9108_row5_col0{
#             background-color:  #59ac59;
#             color:  #000000;
#         }#T_f9108_row5_col1{
#             background-color:  #2d962d;
#             color:  #000000;
#         }#T_f9108_row5_col4{
#             background-color:  #51a851;
#             color:  #000000;
#         }#T_f9108_row5_col5{
#             background-color:  #018001;
#             color:  #f1f1f1;
#         }#T_f9108_row6_col0{
#             background-color:  #6cb56c;
#             color:  #000000;
#         }#T_f9108_row6_col1{
#             background-color:  #9fce9f;
#             color:  #000000;
#         }#T_f9108_row6_col5{
#             background-color:  #bfdebf;
#             color:  #000000;
#         }</style><table id="T_f9108_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >AcceptedCmp3</th>        <th class="col_heading level0 col1" >AcceptedCmp4</th>        <th class="col_heading level0 col2" >AcceptedCmp5</th>        <th class="col_heading level0 col3" >AcceptedCmp1</th>        <th class="col_heading level0 col4" >AcceptedCmp2</th>        <th class="col_heading level0 col5" >Total accept</th>    </tr>    <tr>        <th class="blank level1" ></th>        <th class="col_heading level1 col0" >mean</th>        <th class="col_heading level1 col1" >mean</th>        <th class="col_heading level1 col2" >mean</th>        <th class="col_heading level1 col3" >mean</th>        <th class="col_heading level1 col4" >mean</th>        <th class="col_heading level1 col5" >mean</th>    </tr>    <tr>        <th class="index_name level0" >Country</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_f9108_level0_row0" class="row_heading level0 row0" >AUS</th>
#                         <td id="T_f9108_row0_col0" class="data row0 col0" >0.056250</td>
#                         <td id="T_f9108_row0_col1" class="data row0 col1" >0.037500</td>
#                         <td id="T_f9108_row0_col2" class="data row0 col2" >0.081250</td>
#                         <td id="T_f9108_row0_col3" class="data row0 col3" >0.043750</td>
#                         <td id="T_f9108_row0_col4" class="data row0 col4" >0.000000</td>
#                         <td id="T_f9108_row0_col5" class="data row0 col5" >0.218750</td>
#             </tr>
#             <tr>
#                         <th id="T_f9108_level0_row1" class="row_heading level0 row1" >CA</th>
#                         <td id="T_f9108_row1_col0" class="data row1 col0" >0.067164</td>
#                         <td id="T_f9108_row1_col1" class="data row1 col1" >0.089552</td>
#                         <td id="T_f9108_row1_col2" class="data row1 col2" >0.078358</td>
#                         <td id="T_f9108_row1_col3" class="data row1 col3" >0.067164</td>
#                         <td id="T_f9108_row1_col4" class="data row1 col4" >0.022388</td>
#                         <td id="T_f9108_row1_col5" class="data row1 col5" >0.324627</td>
#             </tr>
#             <tr>
#                         <th id="T_f9108_level0_row2" class="row_heading level0 row2" >GER</th>
#                         <td id="T_f9108_row2_col0" class="data row2 col0" >0.083333</td>
#                         <td id="T_f9108_row2_col1" class="data row2 col1" >0.091667</td>
#                         <td id="T_f9108_row2_col2" class="data row2 col2" >0.066667</td>
#                         <td id="T_f9108_row2_col3" class="data row2 col3" >0.058333</td>
#                         <td id="T_f9108_row2_col4" class="data row2 col4" >0.016667</td>
#                         <td id="T_f9108_row2_col5" class="data row2 col5" >0.316667</td>
#             </tr>
#             <tr>
#                         <th id="T_f9108_level0_row3" class="row_heading level0 row3" >IND</th>
#                         <td id="T_f9108_row3_col0" class="data row3 col0" >0.087838</td>
#                         <td id="T_f9108_row3_col1" class="data row3 col1" >0.074324</td>
#                         <td id="T_f9108_row3_col2" class="data row3 col2" >0.040541</td>
#                         <td id="T_f9108_row3_col3" class="data row3 col3" >0.047297</td>
#                         <td id="T_f9108_row3_col4" class="data row3 col4" >0.013514</td>
#                         <td id="T_f9108_row3_col5" class="data row3 col5" >0.263514</td>
#             </tr>
#             <tr>
#                         <th id="T_f9108_level0_row4" class="row_heading level0 row4" >SA</th>
#                         <td id="T_f9108_row4_col0" class="data row4 col0" >0.062315</td>
#                         <td id="T_f9108_row4_col1" class="data row4 col1" >0.059347</td>
#                         <td id="T_f9108_row4_col2" class="data row4 col2" >0.062315</td>
#                         <td id="T_f9108_row4_col3" class="data row4 col3" >0.059347</td>
#                         <td id="T_f9108_row4_col4" class="data row4 col4" >0.011869</td>
#                         <td id="T_f9108_row4_col5" class="data row4 col5" >0.255193</td>
#             </tr>
#             <tr>
#                         <th id="T_f9108_level0_row5" class="row_heading level0 row5" >SP</th>
#                         <td id="T_f9108_row5_col0" class="data row5 col0" >0.075799</td>
#                         <td id="T_f9108_row5_col1" class="data row5 col1" >0.081279</td>
#                         <td id="T_f9108_row5_col2" class="data row5 col2" >0.081279</td>
#                         <td id="T_f9108_row5_col3" class="data row5 col3" >0.071233</td>
#                         <td id="T_f9108_row5_col4" class="data row5 col4" >0.014612</td>
#                         <td id="T_f9108_row5_col5" class="data row5 col5" >0.324201</td>
#             </tr>
#             <tr>

# %% [markdown]
# In each column, the darkest green shade one is the country that performed the best in each campaign.
# We see that:
#
#     In campaign 3, "GER", "IND", "SP", "US" perform quite well.
#     In campaign 4, "SP", "IND", "GER", "CA" perform quite well.
#     In campaign 5, "AUS", "CA", "SP" perform quite well.
#     In campaign 1, "SP", "CA" perform quite well.
#     Campaign 2 was doing not very well in any country.
#     For the overall average performance, "CA", "GER", "SP" are the best.

# %% [markdown]
# I'll impute these null values by KNN imputation. KNN imputation is an approach to fill the missing data by using a model to predict the missing values. A range of different models can be used, although a simple k-nearest neighbor (KNN) model has proven to be effective in experiments. The use of a KNN model to predict or fill missing values is referred to as “Nearest Neighbor Imputation” or “KNN imputation.”

# %%
# Building analysis dataset
numeric_analsis = numeric[numeric['Income']!=666666]

# Let's clear redundant features
X_numeric = numeric_analsis.drop(['NumStorePurchases','Enrollment date','Year_Birth','ID','Total products amount'], axis=1)

# Focus on number of store purchases
y = numeric_analsis[['NumStorePurchases']]

# %%
from sklearn.linear_model import Lasso, Ridge
from sklearn.preprocessing import StandardScaler, OneHotEncoder, OrdinalEncoder
from sklearn.feature_selection import f_regression, f_classif, chi2, RFE, VarianceThreshold, SelectPercentile
from sklearn.pipeline import FeatureUnion, Pipeline
from sklearn.impute import KNNImputer

# 1) Preoprocess
# Impute null values
Imputer = KNNImputer(missing_values=np.nan)

# Standardize numeric columns
Scaler = StandardScaler()

numeric_pipe = Pipeline([("Impute", Imputer),
                         ("Scale", Scaler)])

X_numeric_preprocessed = numeric_pipe.fit_transform(X_numeric)

# 2) Building the models
lasso = Lasso(alpha=0.01).fit(X_numeric_preprocessed, y)
ridge = Ridge().fit(X_numeric_preprocessed, y)
F, p = f_regression(X_numeric_preprocessed, y)  # Statistically check how each predictor & target are linearly correlated

# %% [markdown]
# The table below shows a summary of the models we have built. LASSO's coefficient and F-value can tell the importance of each variable.
# I also included the variance of each variable to see the spread of value in each variable.

# %%
index = [
    ['Features','Variance','Lasso','Ridge','F-test','F-test'],
    ['','','Coef','Coef','F-value','p-value']
]

StorePurchases_effect_num = pd.DataFrame(list(zip(X_numeric.columns,
                                          X_numeric.var()/np.nanmean(X_numeric, axis=0),
                                          lasso.coef_, 
                                          ridge.coef_[0], 
                                          F, p))
                                          ,columns=index).set_index('Features')

StorePurchases_effect_num.sort_values(by=('F-test','p-value')).style.background_gradient(sns.light_palette('khaki', as_cmap=True), 
                                                                                                       subset=pd.IndexSlice[:, [('Lasso','Coef'),
                                                                                                                                ('Ridge','Coef'),
                                                                                                                                ('F-test','F-value')]])
# Out:
# <style  type="text/css" >
# #T_bd132_row0_col1,#T_bd132_row0_col3,#T_bd132_row14_col2{
#             background-color:  #f0e68c;
#             color:  #000000;
#         }#T_bd132_row0_col2{
#             background-color:  #f0e795;
#             color:  #000000;
#         }#T_bd132_row1_col1,#T_bd132_row8_col2{
#             background-color:  #f1ebb4;
#             color:  #000000;
#         }#T_bd132_row1_col2{
#             background-color:  #f1eaab;
#             color:  #000000;
#         }#T_bd132_row1_col3{
#             background-color:  #f0e792;
#             color:  #000000;
#         }#T_bd132_row2_col1{
#             background-color:  #f2efd6;
#             color:  #000000;
#         }#T_bd132_row2_col2,#T_bd132_row7_col1,#T_bd132_row11_col2{
#             background-color:  #f1ecc0;
#             color:  #000000;
#         }#T_bd132_row2_col3,#T_bd132_row10_col2,#T_bd132_row21_col2{
#             background-color:  #f1ebb8;
#             color:  #000000;
#         }#T_bd132_row3_col1,#T_bd132_row16_col2{
#             background-color:  #f1ebb6;
#             color:  #000000;
#         }#T_bd132_row3_col2{
#             background-color:  #f1eaac;
#             color:  #000000;
#         }#T_bd132_row3_col3{
#             background-color:  #f1ecbc;
#             color:  #000000;
#         }#T_bd132_row4_col1{
#             background-color:  #f2f0e1;
#             color:  #000000;
#         }#T_bd132_row4_col2,#T_bd132_row6_col3,#T_bd132_row7_col3{
#             background-color:  #f1edc5;
#             color:  #000000;
#         }#T_bd132_row4_col3,#T_bd132_row5_col2,#T_bd132_row18_col2{
#             background-color:  #f1ecbd;
#             color:  #000000;
#         }#T_bd132_row5_col1,#T_bd132_row12_col1{
#             background-color:  #f2eed0;
#             color:  #000000;
#         }#T_bd132_row5_col3,#T_bd132_row20_col2{
#             background-color:  #f1ecc1;
#             color:  #000000;
#         }#T_bd132_row6_col1,#T_bd132_row12_col2,#T_bd132_row22_col2{
#             background-color:  #f1ecbb;
#             color:  #000000;
#         }#T_bd132_row6_col2{
#             background-color:  #f1eab0;
#             color:  #000000;
#         }#T_bd132_row7_col2{
#             background-color:  #f1eab2;
#             color:  #000000;
#         }#T_bd132_row8_col1{
#             background-color:  #f1ecc2;
#             color:  #000000;
#         }#T_bd132_row8_col3{
#             background-color:  #f1edc7;
#             color:  #000000;
#         }#T_bd132_row9_col1,#T_bd132_row15_col2,#T_bd132_row19_col3,#T_bd132_row20_col3,#T_bd132_row21_col3,#T_bd132_row22_col3{
#             background-color:  #f2f1e9;
#             color:  #000000;
#         }#T_bd132_row9_col2,#T_bd132_row9_col3{
#             background-color:  #f1edcb;
#             color:  #000000;
#         }#T_bd132_row10_col1,#T_bd132_row21_col1{
#             background-color:  #f1edca;
#             color:  #000000;
#         }#T_bd132_row10_col3{
#             background-color:  #f2eed2;
#             color:  #000000;
#         }#T_bd132_row11_col1{
#             background-color:  #f2efd8;
#             color:  #000000;
#         }#T_bd132_row11_col3{
#             background-color:  #f2f0e2;
#             color:  #000000;
#         }#T_bd132_row12_col3,#T_bd132_row13_col3{
#             background-color:  #f2f0e4;
#             color:  #000000;
#         }#T_bd132_row13_col1,#T_bd132_row14_col1{
#             background-color:  #f1edcc;
#             color:  #000000;
#         }#T_bd132_row13_col2{
#             background-color:  #f1ebb9;
#             color:  #000000;
#         }#T_bd132_row14_col3,#T_bd132_row15_col3{
#             background-color:  #f2f1e6;
#             color:  #000000;
#         }#T_bd132_row15_col1{
#             background-color:  #f2eed1;
#             color:  #000000;
#         }#T_bd132_row16_col1{
#             background-color:  #f1edc8;
#             color:  #000000;
#         }#T_bd132_row16_col3,#T_bd132_row17_col3,#T_bd132_row18_col3{
#             background-color:  #f2f1e8;
#             color:  #000000;
#         }#T_bd132_row17_col1{
#             background-color:  #f1ebb3;
#             color:  #000000;
#         }#T_bd132_row17_col2{
#             background-color:  #f1eaaa;
#             color:  #000000;
#         }#T_bd132_row18_col1{
#             background-color:  #f2eed4;
#             color:  #000000;
#         }#T_bd132_row19_col1{
#             background-color:  #f1eecc;
#             color:  #000000;
#         }#T_bd132_row19_col2{
#             background-color:  #f1ebba;
#             color:  #000000;
#         }#T_bd132_row20_col1{
#             background-color:  #f2efd9;
#             color:  #000000;
#         }#T_bd132_row22_col1{
#             background-color:  #f2eecf;
#             color:  #000000;
#         }</style><table id="T_bd132_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Variance</th>        <th class="col_heading level0 col1" >Lasso</th>        <th class="col_heading level0 col2" >Ridge</th>        <th class="col_heading level0 col3" colspan="2">F-test</th>    </tr>    <tr>        <th class="blank level1" ></th>        <th class="col_heading level1 col0" ></th>        <th class="col_heading level1 col1" >Coef</th>        <th class="col_heading level1 col2" >Coef</th>        <th class="col_heading level1 col3" >F-value</th>        <th class="col_heading level1 col4" >p-value</th>    </tr>    <tr>        <th class="index_name level0" >Features</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_bd132_level0_row0" class="row_heading level0 row0" >MntWines</th>
#                         <td id="T_bd132_row0_col0" class="data row0 col0" >372.646093</td>
#                         <td id="T_bd132_row0_col1" class="data row0 col1" >1.231232</td>
#                         <td id="T_bd132_row0_col2" class="data row0 col2" >1.243485</td>
#                         <td id="T_bd132_row0_col3" class="data row0 col3" >1568.318418</td>
#                         <td id="T_bd132_row0_col4" class="data row0 col4" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_bd132_level0_row1" class="row_heading level0 row1" >Income</th>
#                         <td id="T_bd132_row1_col0" class="data row1 col0" >8916.368917</td>
#                         <td id="T_bd132_row1_col1" class="data row1 col1" >0.450578</td>
#                         <td id="T_bd132_row1_col2" class="data row1 col2" >0.492011</td>
#                         <td id="T_bd132_row1_col3" class="data row1 col3" >1465.748501</td>
#                         <td id="T_bd132_row1_col4" class="data row1 col4" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_bd132_level0_row2" class="row_heading level0 row2" >NumCatalogPurchases</th>
#                         <td id="T_bd132_row2_col0" class="data row2 col0" >3.209822</td>
#                         <td id="T_bd132_row2_col1" class="data row2 col1" >-0.209374</td>
#                         <td id="T_bd132_row2_col2" class="data row2 col2" >-0.259685</td>
#                         <td id="T_bd132_row2_col3" class="data row2 col3" >823.152208</td>
#                         <td id="T_bd132_row2_col4" class="data row2 col4" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_bd132_level0_row3" class="row_heading level0 row3" >NumWebPurchases</th>
#                         <td id="T_bd132_row3_col0" class="data row3 col0" >1.890722</td>
#                         <td id="T_bd132_row3_col1" class="data row3 col1" >0.425140</td>
#                         <td id="T_bd132_row3_col2" class="data row3 col2" >0.425400</td>
#                         <td id="T_bd132_row3_col3" class="data row3 col3" >756.325434</td>
#                         <td id="T_bd132_row3_col4" class="data row3 col4" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_bd132_level0_row4" class="row_heading level0 row4" >Kidhome</th>

# %% [markdown]
# For simplicity, we plot the coefficient of LASSO and F-value of F-test in the bar graphs below.

# %%
plt.figure(figsize=(7,7))
StorePurchases_effect_num['Lasso']['Coef'].sort_values().plot(kind='barh')
plt.xlabel('Lasso coef')
plt.title('LASSO analysis')
plt.show()

# %% [markdown]
# Considering Lasso coefficient, we see that
#
#     Features having positive effect to the number of store purchases in decreasing order is 'MntWines', 'NumDealsPurchases', 'NumWebPurchases', 'MntFruits', 'MntFishProducts'.
#     Features having negative effect to the number of store purchases in decreasing order is NumWebVisitsMonth, Kidhome, Response.

# %%
plt.figure(figsize=(7,7))
StorePurchases_effect_num['F-test']['F-value'].sort_values().plot(kind='barh')
plt.xlabel('F-value')
plt.title('F-test')
plt.show()

# %% [markdown]
# Apart from statistical methods(LASSO and F-test) that measure te linear effect, we'll also perform Recursive Feature Elimination which is a feature selection method based on ML.

# %%
from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor()

rfe = RFE(estimator = rf, n_features_to_select = 1.0, verbose=1).fit(X_numeric_preprocessed, y)

# %%
pd.Series(dict(zip(X_numeric.columns, rfe.ranking_)), name='Rank').to_frame().sort_values(by='Rank')
# Out:
#                           Rank
# Age                          1
# AcceptedCmp2                 1
# AcceptedCmp1                 1
# AcceptedCmp5                 1
# AcceptedCmp4                 1
# AcceptedCmp3                 1
# NumWebVisitsMonth            1
# NumCatalogPurchases          1
# NumWebPurchases              1
# NumDealsPurchases            1
# Response                     1
# MntGoldProds                 1
# MntFishProducts              1
# MntMeatProducts              1
# MntFruits                    1
# MntWines                     1
# Days since last purchase     1
# Enroll_at_age                1
# Teenhome                     1
# Kidhome                      1
# Income                       1
# MntSweetProducts             1
# Complain                     1

# %% [markdown]
# We can conclude from many methods we performed before that 'MntWines' is the most significant factor related to the number of store purchases.

# %%
category_NumStore = numeric[['NumStorePurchases']].join(category)
category_NumStore.head()
# Out:
#        NumStorePurchases   Education Marital_Status Country
# ID
# 1826                   6  Graduation       Divorced      SP
# 1                      7  Graduation         Single      CA
# 10476                  5  Graduation        Married      US
# 1386                   2  Graduation       Together     AUS
# 5371                   2  Graduation         Single      SP

# %%
sns.catplot(kind='box', data=category_NumStore.query("Country!='ME'"), col='Country', x='Education', y='NumStorePurchases',  col_wrap=4)
plt.show()

# %% [markdown]
# Obviously, we can see that 'Basic' education level seems to have the lowest number of store purchases in all countries.
#
# On the other hand, there is no obvious trend in marital status in each country as shown in the plot below. However, from the plot below, we might conclude that widows in the US are less likely to purchase in-store while those in AUS, IND, GER are tended to purchase in-store.

# %%
sns.catplot(kind='bar', data=category_NumStore.query("(Country!='ME') and (Marital_Status not in ['YOLO','Alone','Absurd'])"), 
            col='Country', x='Marital_Status', y='NumStorePurchases',  col_wrap=4)
plt.show()

# %% [markdown]
# Lastly, we have to look up to the average number of store purchases in each country and in each education level to see if there's some bias in the number of samples.

# %%
fig, ax = plt.subplots(1,3, sharey=True)
fig.set_size_inches(15,5)

for i,col in list(enumerate(['Education', 'Marital_Status', 'Country'])):
    sns.countplot(data=data, x='Education',  ax=ax[i])

for ax_i in ax:
    ax_i.xaxis.set_label_coords(0.5, 1.05)
    plt.setp( ax_i.xaxis.get_majorticklabels(), rotation=40 )

plt.show()

# %% [markdown]
# We can't confidentially tell that 'Basic' education level have the lowest number of store purchases in all countries because we don't have enough data to say so. But these visualization give us a roughly say. If we have more data, we'll have more confident to that.

# %% [markdown]
# Let's see the distribution of purchases in each country and then
# a table that summary important statistics of purchases in each country.

# %%
temp = Purchases.join(data[['Country','ID']])

fig, ax = plt.subplots(2,4)
fig.set_size_inches(20,7)
i=0

import itertools 
axes = list(itertools.chain(ax[0],ax[1]))

for c in temp.Country.unique():
    sns.histplot(data=temp[temp['Country'] == c], x='Total purchase', label=c, ax=axes[i], bins=15)
    axes[i].legend()
    i+=1
plt.show()

# %%
summary_purchase_country = np.sum(Purchases, axis=1).to_frame('Total purchases').join(category[['Country']]).groupby(by='Country').agg(['count','sum','mean','median','std'])

summary_purchase_country
# Out:
#         Total purchases
#                   count    sum       mean median        std
# Country
# AUS                 160   6282  39.262500     40  14.302433
# CA                  268  11036  41.179104     40  14.859568
# GER                 120   4818  40.150000     40  14.935520
# IND                 148   5826  39.364865     36  14.704411
# ME                    3    154  51.333333     48  15.275252
# SA                  337  13798  40.943620     40  14.099976
# SP                 1095  43744  39.948858     38  14.562641
# US                  109   4742  43.504587     42  15.227062

# %%
from scipy.stats import norm

US_mean = summary_purchase_country.loc['US', ('Total purchases','mean')]
US_std = summary_purchase_country.loc['US', ('Total purchases','std')]
US_n = summary_purchase_country.loc['US', ('Total purchases','count')]

for country in summary_purchase_country.index:
    if country == 'US':break
    other_mean = summary_purchase_country.loc[country, ('Total purchases','mean')]
    x = (US_mean-other_mean)/(US_std/US_n**0.5)
    print('mean "US" > mean "'+country.upper()+'" p-value = '+str(norm.sf(x)))
# Out:
# mean "US" > mean "AUS" p-value = 0.001815537848326719
# mean "US" > mean "CA" p-value = 0.055417908161260694
# mean "US" > mean "GER" p-value = 0.010722851660792366
# mean "US" > mean "IND" p-value = 0.0022672597368808955
# mean "US" > mean "ME" p-value = 0.9999999601295373
# mean "US" > mean "SA" p-value = 0.03955227838776489
# mean "US" > mean "SP" p-value = 0.007385297396392279

# %% [markdown]
# If we ignore "ME", because of its too few observation, we still can not conclude that US has significantly better than the Rest of the World in term of total purchase since p-value of μus>μca is 0.0554 which is not less than 0.05.

# %% [markdown]
#     people who spent an above average amount on gold in the last 2 years would have more in store purchases.
#
# From the histogram and boxplot below, we can conclude that people who spent an above-average amount on gold have more in-store purchases.

# %%
Gold_avg = np.mean(Products['MntGoldProds'])

mask = Products['MntGoldProds']>=Gold_avg

Above_gold = Products[mask].index
Below_gold = Products[~mask].index

fig,ax = plt.subplots(1,2)
fig.set_size_inches(15,5)
sns.histplot(ax=ax[0], data=Purchases[mask], x='NumStorePurchases', kde=True, label='Purchase Gold Above Avg.', color='indigo',element='step')
sns.histplot(ax=ax[0], data=Purchases[~mask], x='NumStorePurchases', kde=True, label='Below', color='darkorange', element='step')

temp = Purchases.join(mask)
temp['MntGoldProds'] = temp['MntGoldProds'].replace({True:'Gold above avg.', False:'Gold below avg.'})
sns.boxplot(ax=ax[1], data=temp, y='NumStorePurchases', x='MntGoldProds', palette={'Gold above avg.':'indigo','Gold below avg.':'darkorange'})

ax[0].legend()
plt.show()

# %% [markdown]
# do "Married PhD candidates" have a significant relation with amount spent on fish? What other factors are significantly related to amount spent on fish?

# %%
PhD_Married = (category['Education']=='PhD') & (category['Marital_Status']=='Married')

numeric.loc[PhD_Married,['MntFishProducts']].describe().join(numeric.loc[~PhD_Married,['MntFishProducts']].describe(),
                                                            lsuffix='_PhD&Marrid',
                                                            rsuffix='_Not')
# Out:
#        MntFishProducts_PhD&Marrid  MntFishProducts_Not
# count                  192.000000          2048.000000
# mean                    27.015625            38.510742
# std                     41.997940            55.572773
# min                      0.000000             0.000000
# 25%                      0.000000             3.000000
# 50%                      4.000000            12.000000
# 75%                     38.000000            50.250000
# max                    193.000000           259.000000

# %% [markdown]
# From the summary table above, we clearly see that "Married PhD candidates" doesn't have a significant relation with amount spent on fish.

# %% [markdown]
# what is the key factor related to amount spent on fish? Let's first see the correlation between other numerical features and 'MntFishProducts'.

# %%
Customers.drop(['Year_Birth','Enrollment date'], axis=1)\
.join([Purchases, Products, Campaigns])\
.corr()[['MntFishProducts']]\
.style.background_gradient(sns.light_palette('green', as_cmap=True))
# Out:
# <style  type="text/css" >
# #T_76f46_row0_col0{
#             background-color:  #5bad5b;
#             color:  #000000;
#         }#T_76f46_row1_col0{
#             background-color:  #e1eee1;
#             color:  #000000;
#         }#T_76f46_row2_col0{
#             background-color:  #c4e0c4;
#             color:  #000000;
#         }#T_76f46_row3_col0,#T_76f46_row17_col0,#T_76f46_row21_col0{
#             background-color:  #a2cfa2;
#             color:  #000000;
#         }#T_76f46_row4_col0{
#             background-color:  #b9dbb9;
#             color:  #000000;
#         }#T_76f46_row5_col0{
#             background-color:  #73b873;
#             color:  #000000;
#         }#T_76f46_row6_col0{
#             background-color:  #4ba54b;
#             color:  #000000;
#         }#T_76f46_row7_col0{
#             background-color:  #57ab57;
#             color:  #000000;
#         }#T_76f46_row8_col0{
#             background-color:  #ebf3eb;
#             color:  #000000;
#         }#T_76f46_row9_col0{
#             background-color:  #6ab46a;
#             color:  #000000;
#         }#T_76f46_row10_col0{
#             background-color:  #61b061;
#             color:  #000000;
#         }#T_76f46_row11_col0{
#             background-color:  #41a041;
#             color:  #000000;
#         }#T_76f46_row12_col0{
#             background-color:  #46a246;
#             color:  #000000;
#         }#T_76f46_row13_col0{
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }#T_76f46_row14_col0{
#             background-color:  #44a144;
#             color:  #000000;
#         }#T_76f46_row15_col0{
#             background-color:  #5eae5e;
#             color:  #000000;
#         }#T_76f46_row16_col0{
#             background-color:  #3a9c3a;
#             color:  #000000;
#         }#T_76f46_row18_col0{
#             background-color:  #a0cea0;
#             color:  #000000;
#         }#T_76f46_row19_col0{
#             background-color:  #82c082;
#             color:  #000000;
#         }#T_76f46_row20_col0{
#             background-color:  #78bb78;
#             color:  #000000;
#         }</style><table id="T_76f46_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >MntFishProducts</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_76f46_level0_row0" class="row_heading level0 row0" >Income</th>
#                         <td id="T_76f46_row0_col0" class="data row0 col0" >0.438871</td>
#             </tr>
#             <tr>
#                         <th id="T_76f46_level0_row1" class="row_heading level0 row1" >Kidhome</th>
#                         <td id="T_76f46_row1_col0" class="data row1 col0" >-0.387644</td>
#             </tr>
#             <tr>
#                         <th id="T_76f46_level0_row2" class="row_heading level0 row2" >Teenhome</th>
#                         <td id="T_76f46_row2_col0" class="data row2 col0" >-0.204187</td>
#             </tr>
#             <tr>
#                         <th id="T_76f46_level0_row3" class="row_heading level0 row3" >Days since last purchase</th>
#                         <td id="T_76f46_row3_col0" class="data row3 col0" >0.001079</td>
#             </tr>
#             <tr>
#                         <th id="T_76f46_level0_row4" class="row_heading level0 row4" >NumDealsPurchases</th>
#                         <td id="T_76f46_row4_col0" class="data row4 col0" >-0.139361</td>
#             </tr>
#             <tr>
#                         <th id="T_76f46_level0_row5" class="row_heading level0 row5" >NumWebPurchases</th>
#                         <td id="T_76f46_row5_col0" class="data row5 col0" >0.293681</td>
#             </tr>
#             <tr>
#                         <th id="T_76f46_level0_row6" class="row_heading level0 row6" >NumCatalogPurchases</th>
#                         <td id="T_76f46_row6_col0" class="data row6 col0" >0.534478</td>
#             </tr>
#             <tr>
#                         <th id="T_76f46_level0_row7" class="row_heading level0 row7" >NumStorePurchases</th>
#                         <td id="T_76f46_row7_col0" class="data row7 col0" >0.459855</td>
#             </tr>
#             <tr>
#                         <th id="T_76f46_level0_row8" class="row_heading level0 row8" >NumWebVisitsMonth</th>
#                         <td id="T_76f46_row8_col0" class="data row8 col0" >-0.446003</td>
#             </tr>
#             <tr>
#                         <th id="T_76f46_level0_row9" class="row_heading level0 row9" >Total purchase</th>
#                         <td id="T_76f46_row9_col0" class="data row9 col0" >0.345769</td>
#             </tr>
#             <tr>
#                         <th id="T_76f46_level0_row10" class="row_heading level0 row10" >MntWines</th>
#                         <td id="T_76f46_row10_col0" class="data row10 col0" >0.399753</td>
#             </tr>
#             <tr>
#                         <th id="T_76f46_level0_row11" class="row_heading level0 row11" >MntFruits</th>
#                         <td id="T_76f46_row11_col0" class="data row11 col0" >0.594804</td>
#             </tr>
#             <tr>
#                         <th id="T_76f46_level0_row12" class="row_heading level0 row12" >MntMeatProducts</th>
#                         <td id="T_76f46_row12_col0" class="data row12 col0" >0.568402</td>
#             </tr>
#             <tr>
#                         <th id="T_76f46_level0_row13" class="row_heading level0 row13" >MntFishProducts</th>
#                         <td id="T_76f46_row13_col0" class="data row13 col0" >1.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_76f46_level0_row14" class="row_heading level0 row14" >MntSweetProducts</th>
#                         <td id="T_76f46_row14_col0" class="data row14 col0" >0.579870</td>
#             </tr>
#             <tr>
#                         <th id="T_76f46_level0_row15" class="row_heading level0 row15" >MntGoldProds</th>
#                         <td id="T_76f46_row15_col0" class="data row15 col0" >0.422875</td>
#             </tr>
#             <tr>
#                         <th id="T_76f46_level0_row16" class="row_heading level0 row16" >Total</th>
#                         <td id="T_76f46_row16_col0" class="data row16 col0" >0.642818</td>
#             </tr>
#             <tr>
#                         <th id="T_76f46_level0_row17" class="row_heading level0 row17" >AcceptedCmp3</th>
#                         <td id="T_76f46_row17_col0" class="data row17 col0" >0.000357</td>
#             </tr>
#             <tr>
#                         <th id="T_76f46_level0_row18" class="row_heading level0 row18" >AcceptedCmp4</th>
#                         <td id="T_76f46_row18_col0" class="data row18 col0" >0.016843</td>
#             </tr>
#             <tr>
#                         <th id="T_76f46_level0_row19" class="row_heading level0 row19" >AcceptedCmp5</th>
#                         <td id="T_76f46_row19_col0" class="data row19 col0" >0.199578</td>
#             </tr>
#             <tr>
#                         <th id="T_76f46_level0_row20" class="row_heading level0 row20" >AcceptedCmp1</th>
#                         <td id="T_76f46_row20_col0" class="data row20 col0" >0.260762</td>
#             </tr>
#             <tr>
#                         <th id="T_76f46_level0_row21" class="row_heading level0 row21" >AcceptedCmp2</th>
#                         <td id="T_76f46_row21_col0" class="data row21 col0" >0.002577</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# From the correlation table above, the darker the color shade is the greater relation on 'MntFishProducts' each variable has.

# %% [markdown]
# we need to see if there are some categorical variables that can be related to 'MntFishProducts'.

# %%
fig, ax = plt.subplots(1,3, sharey=True)
fig.set_size_inches(20,7)
sns.boxplot(data=data[data['Country']!='ME'], 
            x='Country', y='MntFishProducts',
            ax=ax[0])

sns.boxplot(data=data.query('Marital_Status not in  ["YOLO","Alone","Absurd"]'), 
            x='Marital_Status', y='MntFishProducts',
            ax=ax[1])

sns.boxplot(data=data, x='Education', y='MntFishProducts',ax=ax[2])

fig.tight_layout()
fig.suptitle('Relationship between each categorical variable\nand amount spent on Fish', fontsize=18, y=1.07)
plt.show()

# %% [markdown]
# From the "Relationship between each categorical variable and amount spent on Fish" graphs we see that:
#
#     In 'Country' variable, we see no difference in each country on 'MntFishProducts'.
#     In 'Marital_Status' variable, Widow tends to have more 'MntFishProducts'.
#     In 'Education' variable, 'Graduation' and '2n Cycle' tends to have more 'MntFishProducts'.

# %%
sns.catplot(kind='box', data = data.query('(Marital_Status not in ["YOLO","Absurd","Alone"]) and (Country != "ME")'), 
            x ='Marital_Status', 
            y ='MntFishProducts', 
            col='Country', col_wrap=4)
plt.suptitle('In each country, \nAmount spent on Fish in each marital status', fontsize=18, y=1.07)

plt.show()

# %% [markdown]
# From the "In each country, Amount spent on Fish in each marital status" graphs we see that:
#
#     Widows from "GER" and "IND" tend to spend on fish significantly more than others. While the Divorced from those country have a opposite trend.

# %%
sns.catplot(kind='box', data = data.query('(Marital_Status not in ["YOLO","Absurd","Alone"]) and (Country != "ME")'), 
            x ='Education', 
            y ='MntFishProducts', 
            col='Country', col_wrap=4)
plt.suptitle('In each country, \nAmount spent on Fish in each education level', fontsize=18, y=1.07)

plt.show()

# %% [markdown]
# From the "In each country, Amount spent on Fish in each education level" graphs we see that:
#
#     Only 'Graduation' and '2n Cycle' in 'SP', 'US', and 'SA' spend on fish more than others. But not for other countries.
